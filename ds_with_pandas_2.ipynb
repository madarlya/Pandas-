# %% [markdown]
# # 50 pandas puzzle

# %% [markdown]
# ## Section 1 -- Loading & Exploring the Data

# %% [markdown]
# ### Question 1: Load csv file into a Dataframe

# %%
import pandas as pd
import os

# %%
df = pd.read_csv(r"C:\PYTHON\Pandas\ds_with_pandas\all_data.csv")
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### Question 2: Find the total Rows & Columns

# %%
df.shape
# Out:
# (186850, 6)

# %% [markdown]
# ### Question 3: view the first 5 rows

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### Question 4: last 5 rows

# %%
df.tail()
# Out:
#        Order ID                 Product Quantity Ordered Price Each  \
# 186845   259353  AAA Batteries (4-pack)                3       2.99
# 186846   259354                  iPhone                1        700
# 186847   259355                  iPhone                1        700
# 186848   259356  34in Ultrawide Monitor                1     379.99
# 186849   259357    USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# 186845  09/17/19 20:56   840 Highland St, Los Angeles, CA 90001
# 186846  09/01/19 16:00  216 Dogwood St, San Francisco, CA 94016
# 186847  09/23/19 07:39     220 12th St, San Francisco, CA 94016
# 186848  09/19/19 17:30   511 Forest St, San Francisco, CA 94016
# 186849  09/30/19 00:18   250 Meadow St, San Francisco, CA 94016

# %% [markdown]
# ### Question 5: print all column names

# %%
df.columns.to_list()
# Out:
# ['Order ID',
#  'Product',
#  'Quantity Ordered',
#  'Price Each',
#  'Order Date',
#  'Purchase Address']

# %% [markdown]
# ### Question 6: check the data types

# %%
df.dtypes
# Out:
# Order ID            str
# Product             str
# Quantity Ordered    str
# Price Each          str
# Order Date          str
# Purchase Address    str
# dtype: object

# %% [markdown]
# ### Question 7: get a full summary of the DataFrame

# %%
df.info
# Out:
# <bound method DataFrame.info of        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %% [markdown]
# ### Question 8: print the list of all unique 'Products'

# %%
df['Product'].unique()
# Out:
# <StringArray>
# [      'USB-C Charging Cable',                          nan,
#  'Bose SoundSport Headphones',               'Google Phone',
#            'Wired Headphones',         'Macbook Pro Laptop',
#    'Lightning Charging Cable',     '27in 4K Gaming Monitor',
#       'AA Batteries (4-pack)',   'Apple Airpods Headphones',
#      'AAA Batteries (4-pack)',                     'iPhone',
#               'Flatscreen TV',           '27in FHD Monitor',
#                '20in Monitor',                   'LG Dryer',
#             'ThinkPad Laptop',            'Vareebadd Phone',
#          'LG Washing Machine',     '34in Ultrawide Monitor',
#                     'Product']
# Length: 21, dtype: str

# %% [markdown]
# ### Question 9: count how many times each product appear

# %%
len(df['Product'].unique())
# Out:
# 21

# %% [markdown]
# ### Question 10: print a random sample of 10 rows

# %%
df.sample(10)
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 114555   170883                Google Phone                1        600
# 108420   165008    Apple Airpods Headphones                1        150
# 45231    309829        USB-C Charging Cable                1      11.95
# 86838    232060      AAA Batteries (4-pack)                2       2.99
# 2031     178493               Flatscreen TV                1        300
# 73537    146937        USB-C Charging Cable                1      11.95
# 135794   208660       AA Batteries (4-pack)                1       3.84
# 137750   279395  Bose SoundSport Headphones                1      99.99
# 2792     179234    Lightning Charging Cable                1      14.95
# 120077   176162      AAA Batteries (4-pack)                2       2.99
#
#             Order Date                         Purchase Address
# 114555  03/31/19 21:10        931 Chestnut St, Boston, MA 02215
# ...

# %% [markdown]
# ## Section 2 -- Finding & Handling missing Values

# %% [markdown]
# ### Question 11: count missing values in ecery column

# %%
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %% [markdown]
# ### Question 12: find the total numbeer of miising values in hole dataset

# %%
df.isnull().sum().sum()
# Out:
# np.int64(3270)

# %% [markdown]
# ### Question 13: drop all rows that have any missing value

# %%
df.dropna(inplace=True)

# %% [markdown]
# ### Question 14: check if there are any duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(618)

# %% [markdown]
# ### Question 15: Remove all duplicate rows from the dataset

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (185687, 6)

# %% [markdown]
# ### Question 16: check if the Order Date column has any nulls after cleaning

# %%
df['Order Date'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Question 17: fill missing valused if their exist

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %% [markdown]
# ## Section 3 -- Column operations

# %% [markdown]
# ### Question 21: print the quantity order column

# %%
# df['Quantity Ordered']
df.head(2)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 2   176559  Bose SoundSport Headphones                1      99.99
#
#        Order Date                   Purchase Address
# 0  04/19/19 08:46       917 1st St, Dallas, TX 75001
# 2  04/07/19 22:30  682 Chestnut St, Boston, MA 02215

# %% [markdown]
# ### Question 22: convert Quantity order column into integer type

# %%
df= df[df['Quantity Ordered'] != 'Quantity Ordered']

# %%
df= df.reset_index(drop=True)

# %%
df = df[df['Quantity Ordered'].str.isnumeric() == True]
df = df.reset_index(drop=True)

# %%
df['Quantity Ordered'] = df['Quantity Ordered'].astype(int)

# %% [markdown]
# ### Question 23: convert price each column to float type

# %%
pd.to_numeric(df['Price Each'])
df = df[df['Order ID'].str.isnumeric() == True]
df = df.reset_index(drop=True)

# %%
df['Price Each'] = df['Price Each'].astype(float)

# %% [markdown]
# ### Question 24: add a new column called revenue

# %%
df['Revenue'] = df['Quantity Ordered'] * df['Price Each']
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Revenue
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001   600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    11.99

# %% [markdown]
# ### Question 25: find the maximum price in the price each column

# %%
df['Price Each'].max()
# Out:
# np.float64(1700.0)

# %% [markdown]
# ### Question 26: find the minimum price in the price each column

# %%
df['Price Each'].min()
# Out:
# np.float64(2.99)

# %% [markdown]
# ### Question 27: find the average price across all orders

# %%
round(df['Price Each'].mean(),2)
# Out:
# np.float64(184.52)

# %% [markdown]
# ### Question 28: get full statistics of the price Each column

# %%
df['Price Each'].describe()
# Out:
# count    185686.000000
# mean        184.519255
# std         332.843838
# min           2.990000
# 25%          11.950000
# 50%          14.950000
# 75%         150.000000
# max        1700.000000
# Name: Price Each, dtype: float64

# %% [markdown]
# ### Question 29: find the toatl revenue across all orders

# %%
# df['Revenue'].sum()
# (34465537.94)
round(df['Price Each'].sum(),2)
# Out:
# np.float64(34262642.47)

# %% [markdown]
# ### Question 30: find the average order quantity

# %%
df['Quantity Ordered'].mean()
# Out:
# np.float64(1.1245435843305365)

# %% [markdown]
# ## Section 4 -- Filtering & Sorting rows

# %% [markdown]
# ### Question 31: filter all orders where quantity ordered is greater than 1

# %%
bulk_orders = df[df['Quantity Ordered'] > 1]
print(bulk_orders.shape)
# Out:
# (17395, 7)

# %% [markdown]
# ### Question 32: find all orders for a specific product -- Usb-c charging cable

# %%
usbc_orders = df[df['Product'] =='USB-C Charging Cable']
print(usbc_orders.shape)
# Out:
# (21859, 7)

# %% [markdown]
# ### question 33: filter all orders where price each is more than 100

# %%
expensive = df[df['Price Each'] > 100]
print(expensive.shape)
# Out:
# (68900, 7)

# %% [markdown]
# ### question 34: sort the dataframe by price each from highest to lowest

# %%
df_sorted = df.sort_values('Price Each', ascending=False)
print(df_sorted.head())
# Out:
#        Order ID             Product  Quantity Ordered  Price Each  \
# 185634   259308  Macbook Pro Laptop                 1      1700.0
# 8        176565  Macbook Pro Laptop                 1      1700.0
# 185624   259299  Macbook Pro Laptop                 1      1700.0
# 30916    296346  Macbook Pro Laptop                 1      1700.0
# 30895    296325  Macbook Pro Laptop                 1      1700.0
#
#             Order Date                        Purchase Address  Revenue
# 185634  09/26/19 19:16            912 8th St, Boston, MA 02215   1700.0
# 8       04/24/19 10:38  915 Willow St, San Francisco, CA 94016   1700.0
# 185624  09/30/19 23:59  240 Chestnut St, Los Angeles, CA 90001   1700.0
# 30916   12/25/19 07:39         818 Willow St, Boston, MA 02215   1700.0
# 30895   12/28/19 22:52         755 Adams St, Seattle, WA 98101   1700.0

# %% [markdown]
# ### question 35: sort the dataframe by quantity order from lowest to highest

# %%
df.sort_values('Quantity Ordered',ascending=True).head()
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 185684   259356      34in Ultrawide Monitor                 1      379.99
# 176044   250048               Flatscreen TV                 1      300.00
# 176045   250049                20in Monitor                 1      109.99
# 176047   250051  Bose SoundSport Headphones                 1       99.99
# 185668   259341      27in 4K Gaming Monitor                 1      389.99
#
#             Order Date                        Purchase Address  Revenue
# 185684  09/19/19 17:30  511 Forest St, San Francisco, CA 94016   379.99
# 176044  09/29/19 07:03           11 Lake St, Seattle, WA 98101   300.00
# 176045  09/11/19 09:22            320 8th St, Dallas, TX 75001   109.99
# 176047  09/15/19 15:30        828 Ridge St, Portland, OR 97035    99.99
# 185668  09/24/19 22:16         501 Adams St, Seattle, WA 98101   389.99

# %% [markdown]
# ### question 36: Filter orders that have Revenue greater than 500

# %%
max_revenue = df[df['Revenue']> 500]
print(max_revenue)
# Out:
#        Order ID             Product  Quantity Ordered  Price Each  \
# 2        176560        Google Phone                 1      600.00
# 8        176565  Macbook Pro Laptop                 1     1700.00
# 10       176567        Google Phone                 1      600.00
# 17       176574        Google Phone                 1      600.00
# 25       176581              iPhone                 1      700.00
# ...         ...                 ...               ...         ...
# 185651   259324  Macbook Pro Laptop                 1     1700.00
# 185672   259345     ThinkPad Laptop                 1      999.99
# 185677   259350        Google Phone                 1      600.00
# 185682   259354              iPhone                 1      700.00
# 185683   259355              iPhone                 1      700.00
#
#             Order Date                         Purchase Address  Revenue
# 2       04/12/19 14:38     669 Spruce St, Los Angeles, CA 90001   600.00
# ...

# %% [markdown]
# ### question 37: select any product and price each column

# %%
df[['Product','Price Each']].head()
# Out:
#                       Product  Price Each
# 0        USB-C Charging Cable       11.95
# 1  Bose SoundSport Headphones       99.99
# 2                Google Phone      600.00
# 3            Wired Headphones       11.99
# 4            Wired Headphones       11.99

# %% [markdown]
# ### question 38: find all order placed in los angeles

# %%
df['City'] = df['Purchase Address'].apply(lambda x:" ".join(x.split(",")[1]))

# %%
df.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Revenue  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001    23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215    99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001   600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001    11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001    11.99
#
#                       City
# 0              D a l l a s
# 1              B o s t o n
# 2    L o s   A n g e l e s
# 3    L o s   A n g e l e s
# ...

# %%
la__orders = df[df['Purchase Address'].str.contains('Los Angeles')]

# %%
print(la__orders.head())
# Out:
#    Order ID           Product  Quantity Ordered  Price Each      Order Date  \
# 2    176560      Google Phone                 1      600.00  04/12/19 14:38
# 3    176560  Wired Headphones                 1       11.99  04/12/19 14:38
# 4    176561  Wired Headphones                 1       11.99  04/30/19 09:27
# 10   176567      Google Phone                 1      600.00  04/18/19 17:18
# 17   176574      Google Phone                 1      600.00  04/03/19 19:42
#
#                         Purchase Address  Revenue                     City
# 2   669 Spruce St, Los Angeles, CA 90001   600.00    L o s   A n g e l e s
# 3   669 Spruce St, Los Angeles, CA 90001    11.99    L o s   A n g e l e s
# 4      333 8th St, Los Angeles, CA 90001    11.99    L o s   A n g e l e s
# 10     444 7th St, Los Angeles, CA 90001   600.00    L o s   A n g e l e s
# 17     20 Hill St, Los Angeles, CA 90001   600.00    L o s   A n g e l e s

# %% [markdown]
# ### question 39: filter orders where both Quantity > 1 AND price > 50

# %%
df[(df['Quantity Ordered']> 1) & (df['Price Each']> 50)].head()
# Out:
#      Order ID                     Product  Quantity Ordered  Price Each  \
# 158    176710                20in Monitor                 2      109.99
# 264    176809  Bose SoundSport Headphones                 2       99.99
# 603    177139    Apple Airpods Headphones                 2      150.00
# 1261   177765  Bose SoundSport Headphones                 2       99.99
# 1369   177866    Apple Airpods Headphones                 2      150.00
#
#           Order Date                         Purchase Address  Revenue  \
# 158   04/07/19 10:00            848 West St, Dallas, TX 75001   219.98
# 264   04/19/19 01:14     278 13th St, San Francisco, CA 94016   199.98
# 603   04/03/19 14:05  723 Madison St, San Francisco, CA 94016   300.00
# 1261  04/16/19 13:57      528 1st St, New York City, NY 10001   199.98
# 1369  04/06/19 17:11       855 Main St, Los Angeles, CA 90001   300.00
#
#                              City
# 158                   D a l l a s
# 264     S a n   F r a n c i s c o
# ...

# %% [markdown]
# ### question 40: reset the index of the DataFrame after filtering

# %%
df.reset_index(drop=True)
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        176558        USB-C Charging Cable                 2       11.95
# 1        176559  Bose SoundSport Headphones                 1       99.99
# 2        176560                Google Phone                 1      600.00
# 3        176560            Wired Headphones                 1       11.99
# 4        176561            Wired Headphones                 1       11.99
# ...         ...                         ...               ...         ...
# 185681   259353      AAA Batteries (4-pack)                 3        2.99
# 185682   259354                      iPhone                 1      700.00
# 185683   259355                      iPhone                 1      700.00
# 185684   259356      34in Ultrawide Monitor                 1      379.99
# 185685   259357        USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Revenue  \
# ...
